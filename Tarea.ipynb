# %% [markdown]
# Dado que el entrenamiento de redes neuronales es una tarea  muy costosa, **se recomienda ejecutar el notebooks en [Google Colab](https://colab.research.google.com)**, por supuesto también se puede ejecutar en local.
#
# Al entrar en [Google Colab](https://colab.research.google.com) bastará con hacer click en `upload` y subir este notebook. No olvide luego descargarlo en `File->Download .ipynb`
#
# **El examen deberá ser entregado con las celdas ejecutadas, si alguna celda no está ejecutadas no se contará.**

# %% [markdown]
# El examen se divide en preguntas de código y preguntas teóricas, con la puntuación que se indica a continuación. La puntuación máxima será 10.
#
# - [Actividad 1: Redes Densas](#actividad_1): 10 pts
#     - Correcta normalización: máximo de 0.5 pts
#     - [Cuestión 1](#1.1): 1.5 pts
#     - [Cuestión 2](#1.2): 1.5 pts
#     - [Cuestión 3](#1.3): 1.5 pts
#     - [Cuestión 4](#1.4): 1 pts
#     - [Cuestión 5](#1.5): 1 pts
#     - [Cuestión 6](#1.6): 1 pts
#     - [Cuestión 7](#1.7): 1 pts
#     - [Cuestión 8](#1.8): 1 pts

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# <a name='actividad_1'></a>
# # Actividad 1: Redes Densas
#
# Para esta actividad vamos a utilizar el [wine quality dataset](https://archive.ics.uci.edu/ml/datasets/wine+quality). Con el que trataremos de predecir la calidad del vino.
#
# La calidad del vino puede tomar valores decimales (por ejemplo 7.25), independientemente de que en el dataset de entrenamiento sean números enteros. Por lo tanto, el problema es una `regresión`.
#
# **Puntuación**:
#
# Normalizar las features correctamente (x_train, x_test): 0.5 pts
#
# - Correcta normalización: máximo de 0.5 pts
# - [Cuestión 1](#1.1): 1 pt
# - [Cuestión 2](#1.2): 1 pt
# - [Cuestión 3](#1.3): 0.5 pts
# - [Cuestión 4](#1.4): 0.5 pts
# - [Cuestión 5](#1.5): 0.5 pts
# - [Cuestión 6](#1.6): 0.5 pts
# - [Cuestión 7](#1.7): 0.5 pts
# - [Cuestión 8](#1.8): 0.5 pts

# %%
# Descargar los datos con pandas
df_red = pd.read_csv(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv',
    sep=';'
)
df_white = pd.read_csv(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv',
    sep=';'
)
df = pd.concat([df_red, df_white])

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
feature_names = [
    'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides',
    'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol'
]


# separar features y target
y = df.pop('quality').values
X = df.copy().values

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

print('x_train, y_train shapes:', x_train.shape, y_train.shape)
print('x_test, y_test shapes:', x_test.shape, y_test.shape)
print('Some qualities: ', y_train[:5])
# Out:
# x_train, y_train shapes: (4872, 11) (4872,)
# x_test, y_test shapes: (1625, 11) (1625,)
# Some qualities:  [6 7 8 5 6]

# %%
## Si quiere, puede normalizar las features

# %% [markdown]
# <a name='1.1'></a>
# ## Cuestión 1: Cree un modelo secuencial que contenga 4 capas ocultas(hidden layers), con más de 60 neuronas  por capa, sin regularización y obtenga los resultados.
#
# Puntuación:
# - Obtener el modelo correcto: 0.8 pts
# - Compilar el modelo: 0.1pts
# - Acertar con la función de pérdida: 0.1 pts

# %%
model = tf.keras.models.Sequential([
    keras.Input(shape=(11,)),
    layers.Dense(64, activation='relu', name='hidden1'),
    layers.Dense(64, activation='relu', name='hidden2'),
    layers.Dense(64, activation='relu', name='hidden3'),
    layers.Dense(64, activation='relu', name='hidden4'),
    layers.Dense(1, name='output')
])

# %%
# Compilación del modelo
# Código aquí
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %%
# No modifique el código
model.fit(x_train,
          y_train,
          epochs=200,
          batch_size=32,
          validation_split=0.2,
          verbose=1)
# Out:
# Epoch 1/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 5.2016 - mae: 1.6841 - val_loss: 0.8259 - val_mae: 0.7135
# Epoch 2/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7048 - mae: 0.6603 - val_loss: 0.6617 - val_mae: 0.6404
# Epoch 3/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6547 - mae: 0.6315 - val_loss: 0.7608 - val_mae: 0.6748
# Epoch 4/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6436 - mae: 0.6327 - val_loss: 0.6382 - val_mae: 0.6316
# Epoch 5/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6748 - mae: 0.6376 - val_loss: 0.6738 - val_mae: 0.6341
# Epoch 6/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6033 - mae: 0.6069 - val_loss: 0.6178 - val_mae: 0.6158
# Epoch 7/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5791 - mae: 0.5936 - val_loss: 0.5953 - val_mae: 0.6105
# Epoch 8/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6529 - mae: 0.6307 - val_loss: 0.6296 - val_mae: 0.6174
# Epoch 9/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6509 - mae: 0.6292 - val_loss: 0.6309 - val_mae: 0.6106
# Epoch 10/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6078 - mae: 0.6056 - val_loss: 0.6018 - val_mae: 0.6136
# Epoch 11/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5932 - mae: 0.6044 - val_loss: 0.6193 - val_mae: 0.6168
# Epoch 12/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5862 - mae: 0.5955 - val_loss: 0.5884 - val_mae: 0.5947
# Epoch 13/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6355 - mae: 0.6172 - val_loss: 0.6581 - val_mae: 0.6411
# Epoch 14/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5956 - mae: 0.6011 - val_loss: 0.5978 - val_mae: 0.6243
# Epoch 15/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6092 - mae: 0.6101 - val_loss: 0.5913 - val_mae: 0.6118
# Epoch 16/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6246 - mae: 0.6207 - val_loss: 0.5842 - val_mae: 0.5974
# Epoch 17/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5602 - mae: 0.5846 - val_loss: 0.5436 - val_mae: 0.5817
# Epoch 18/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6663 - mae: 0.6350 - val_loss: 0.5612 - val_mae: 0.6025
# Epoch 19/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5556 - mae: 0.5814 - val_loss: 0.5758 - val_mae: 0.5933
# Epoch 20/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5730 - mae: 0.5925 - val_loss: 0.5516 - val_mae: 0.5908
# Epoch 21/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6446 - mae: 0.6238 - val_loss: 0.5432 - val_mae: 0.5824
# Epoch 22/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5611 - mae: 0.5858 - val_loss: 0.5541 - val_mae: 0.5835
# Epoch 23/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5531 - mae: 0.5792 - val_loss: 0.7584 - val_mae: 0.7013
# Epoch 24/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6017 - mae: 0.6029 - val_loss: 0.5296 - val_mae: 0.5764
# Epoch 25/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5514 - mae: 0.5726 - val_loss: 0.7122 - val_mae: 0.6503
# Epoch 26/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5932 - mae: 0.5998 - val_loss: 0.5751 - val_mae: 0.6071
# Epoch 27/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5670 - mae: 0.5886 - val_loss: 0.8223 - val_mae: 0.7036
# Epoch 28/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5696 - mae: 0.5954 - val_loss: 0.5989 - val_mae: 0.5963
# Epoch 29/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5720 - mae: 0.5924 - val_loss: 0.5422 - val_mae: 0.5861
# Epoch 30/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5620 - mae: 0.5857 - val_loss: 0.5229 - val_mae: 0.5753
# Epoch 31/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5477 - mae: 0.5778 - val_loss: 0.5708 - val_mae: 0.5819
# Epoch 32/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5237 - mae: 0.5643 - val_loss: 0.5178 - val_mae: 0.5707
# Epoch 33/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5653 - mae: 0.5805 - val_loss: 0.6957 - val_mae: 0.6776
# Epoch 34/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5823 - mae: 0.5963 - val_loss: 0.5344 - val_mae: 0.5718
# Epoch 35/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5310 - mae: 0.5708 - val_loss: 0.5641 - val_mae: 0.5813
# Epoch 36/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5454 - mae: 0.5769 - val_loss: 0.5228 - val_mae: 0.5666
# Epoch 37/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5605 - mae: 0.5824 - val_loss: 0.5951 - val_mae: 0.6179
# Epoch 38/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5368 - mae: 0.5714 - val_loss: 0.5078 - val_mae: 0.5616
# Epoch 39/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5209 - mae: 0.5599 - val_loss: 0.5881 - val_mae: 0.6105
# Epoch 40/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5669 - mae: 0.5844 - val_loss: 0.6799 - val_mae: 0.6302
# Epoch 41/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5574 - mae: 0.5800 - val_loss: 0.5093 - val_mae: 0.5642
# Epoch 42/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5687 - mae: 0.5797 - val_loss: 0.5160 - val_mae: 0.5681
# Epoch 43/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5583 - mae: 0.5805 - val_loss: 0.5013 - val_mae: 0.5578
# Epoch 44/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5288 - mae: 0.5669 - val_loss: 0.5684 - val_mae: 0.5935
# Epoch 45/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5409 - mae: 0.5651 - val_loss: 0.5523 - val_mae: 0.5771
# Epoch 46/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5273 - mae: 0.5587 - val_loss: 0.5845 - val_mae: 0.6171
# Epoch 47/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5557 - mae: 0.5828 - val_loss: 0.5148 - val_mae: 0.5746
# Epoch 48/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5563 - mae: 0.5812 - val_loss: 0.5270 - val_mae: 0.5762
# Epoch 49/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5966 - mae: 0.5996 - val_loss: 0.5147 - val_mae: 0.5736
# Epoch 50/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5645 - mae: 0.5883 - val_loss: 0.5011 - val_mae: 0.5596
# Epoch 51/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5587 - mae: 0.5792 - val_loss: 0.5818 - val_mae: 0.6141
# Epoch 52/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5427 - mae: 0.5756 - val_loss: 0.5443 - val_mae: 0.5775
# Epoch 53/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5783 - mae: 0.5902 - val_loss: 0.5769 - val_mae: 0.6069
# Epoch 54/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5507 - mae: 0.5793 - val_loss: 0.5148 - val_mae: 0.5619
# Epoch 55/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5685 - mae: 0.5876 - val_loss: 0.5287 - val_mae: 0.5692
# Epoch 56/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5457 - mae: 0.5765 - val_loss: 0.5794 - val_mae: 0.5835
# Epoch 57/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5405 - mae: 0.5672 - val_loss: 0.5115 - val_mae: 0.5659
# Epoch 58/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4970 - mae: 0.5509 - val_loss: 0.5561 - val_mae: 0.5955
# Epoch 59/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5715 - mae: 0.5875 - val_loss: 0.5332 - val_mae: 0.5699
# Epoch 60/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5325 - mae: 0.5673 - val_loss: 0.5061 - val_mae: 0.5653
# Epoch 61/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5359 - mae: 0.5695 - val_loss: 0.5338 - val_mae: 0.5787
# Epoch 62/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5431 - mae: 0.5706 - val_loss: 0.4978 - val_mae: 0.5635
# Epoch 63/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5229 - mae: 0.5672 - val_loss: 0.4974 - val_mae: 0.5565
# Epoch 64/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5619 - mae: 0.5756 - val_loss: 0.6437 - val_mae: 0.6195
# Epoch 65/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5216 - mae: 0.5589 - val_loss: 0.5113 - val_mae: 0.5713
# Epoch 66/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5256 - mae: 0.5659 - val_loss: 0.5446 - val_mae: 0.5923
# Epoch 67/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5249 - mae: 0.5681 - val_loss: 0.5034 - val_mae: 0.5589
# Epoch 68/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5212 - mae: 0.5614 - val_loss: 0.5652 - val_mae: 0.5825
# Epoch 69/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5073 - mae: 0.5562 - val_loss: 0.5041 - val_mae: 0.5609
# Epoch 70/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5480 - mae: 0.5714 - val_loss: 0.5363 - val_mae: 0.5831
# Epoch 71/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5321 - mae: 0.5664 - val_loss: 0.5318 - val_mae: 0.5742
# Epoch 72/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5312 - mae: 0.5699 - val_loss: 0.5388 - val_mae: 0.5841
# Epoch 73/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5391 - mae: 0.5704 - val_loss: 0.5329 - val_mae: 0.5690
# Epoch 74/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5385 - mae: 0.5722 - val_loss: 0.5056 - val_mae: 0.5688
# Epoch 75/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5351 - mae: 0.5687 - val_loss: 0.5556 - val_mae: 0.5946
# Epoch 76/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5167 - mae: 0.5605 - val_loss: 0.5031 - val_mae: 0.5588
# Epoch 77/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5145 - mae: 0.5613 - val_loss: 0.5292 - val_mae: 0.5789
# Epoch 78/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5644 - mae: 0.5785 - val_loss: 0.6133 - val_mae: 0.6045
# Epoch 79/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5524 - mae: 0.5710 - val_loss: 0.5175 - val_mae: 0.5615
# Epoch 80/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5246 - mae: 0.5570 - val_loss: 0.5143 - val_mae: 0.5708
# Epoch 81/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5069 - mae: 0.5538 - val_loss: 0.5166 - val_mae: 0.5757
# Epoch 82/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5096 - mae: 0.5598 - val_loss: 0.6023 - val_mae: 0.5953
# Epoch 83/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5479 - mae: 0.5772 - val_loss: 0.4988 - val_mae: 0.5576
# Epoch 84/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5285 - mae: 0.5678 - val_loss: 0.6200 - val_mae: 0.6111
# Epoch 85/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5193 - mae: 0.5673 - val_loss: 0.5047 - val_mae: 0.5578
# Epoch 86/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5219 - mae: 0.5613 - val_loss: 0.5256 - val_mae: 0.5710
# Epoch 87/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5629 - mae: 0.5917 - val_loss: 0.5427 - val_mae: 0.5750
# Epoch 88/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5109 - mae: 0.5539 - val_loss: 0.4975 - val_mae: 0.5586
# Epoch 89/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5229 - mae: 0.5621 - val_loss: 0.5243 - val_mae: 0.5708
# Epoch 90/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5643 - mae: 0.5804 - val_loss: 0.5144 - val_mae: 0.5684
# Epoch 91/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4864 - mae: 0.5451 - val_loss: 0.5550 - val_mae: 0.5958
# Epoch 92/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5291 - mae: 0.5682 - val_loss: 0.5535 - val_mae: 0.5939
# Epoch 93/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5224 - mae: 0.5582 - val_loss: 0.5295 - val_mae: 0.5655
# Epoch 94/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5108 - mae: 0.5537 - val_loss: 0.5028 - val_mae: 0.5648
# Epoch 95/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5146 - mae: 0.5473 - val_loss: 0.5033 - val_mae: 0.5594
# Epoch 96/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5138 - mae: 0.5534 - val_loss: 0.5420 - val_mae: 0.5899
# Epoch 97/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5263 - mae: 0.5656 - val_loss: 0.4886 - val_mae: 0.5573
# Epoch 98/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5116 - mae: 0.5569 - val_loss: 0.5133 - val_mae: 0.5721
# Epoch 99/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5525 - mae: 0.5759 - val_loss: 0.5018 - val_mae: 0.5629
# Epoch 100/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5136 - mae: 0.5592 - val_loss: 0.4956 - val_mae: 0.5611
# Epoch 101/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5201 - mae: 0.5657 - val_loss: 0.5050 - val_mae: 0.5604
# Epoch 102/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4981 - mae: 0.5525 - val_loss: 0.5762 - val_mae: 0.5850
# Epoch 103/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5028 - mae: 0.5462 - val_loss: 0.5107 - val_mae: 0.5652
# Epoch 104/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5083 - mae: 0.5505 - val_loss: 0.5855 - val_mae: 0.5927
# Epoch 105/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5384 - mae: 0.5748 - val_loss: 0.5238 - val_mae: 0.5657
# Epoch 106/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5262 - mae: 0.5647 - val_loss: 0.5069 - val_mae: 0.5572
# Epoch 107/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5077 - mae: 0.5559 - val_loss: 0.5047 - val_mae: 0.5618
# Epoch 108/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5054 - mae: 0.5520 - val_loss: 0.4983 - val_mae: 0.5603
# Epoch 109/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5225 - mae: 0.5689 - val_loss: 0.5257 - val_mae: 0.5672
# Epoch 110/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5216 - mae: 0.5651 - val_loss: 0.5037 - val_mae: 0.5624
# Epoch 111/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5003 - mae: 0.5486 - val_loss: 0.5230 - val_mae: 0.5798
# Epoch 112/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5165 - mae: 0.5569 - val_loss: 0.5837 - val_mae: 0.5890
# Epoch 113/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5211 - mae: 0.5610 - val_loss: 0.4975 - val_mae: 0.5591
# Epoch 114/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5159 - mae: 0.5566 - val_loss: 0.5752 - val_mae: 0.5841
# Epoch 115/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5165 - mae: 0.5574 - val_loss: 0.5184 - val_mae: 0.5621
# Epoch 116/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5007 - mae: 0.5520 - val_loss: 0.5130 - val_mae: 0.5682
# Epoch 117/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5228 - mae: 0.5619 - val_loss: 0.5025 - val_mae: 0.5585
# Epoch 118/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5155 - mae: 0.5607 - val_loss: 0.5360 - val_mae: 0.5686
# Epoch 119/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5115 - mae: 0.5605 - val_loss: 0.5148 - val_mae: 0.5629
# Epoch 120/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5245 - mae: 0.5616 - val_loss: 0.4998 - val_mae: 0.5586
# Epoch 121/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5190 - mae: 0.5530 - val_loss: 0.5546 - val_mae: 0.5983
# Epoch 122/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5017 - mae: 0.5507 - val_loss: 0.4889 - val_mae: 0.5540
# Epoch 123/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4857 - mae: 0.5426 - val_loss: 0.5274 - val_mae: 0.5652
# Epoch 124/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4909 - mae: 0.5469 - val_loss: 0.5153 - val_mae: 0.5665
# Epoch 125/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5001 - mae: 0.5540 - val_loss: 0.5050 - val_mae: 0.5676
# Epoch 126/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5232 - mae: 0.5604 - val_loss: 0.5188 - val_mae: 0.5724
# Epoch 127/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5128 - mae: 0.5562 - val_loss: 0.5079 - val_mae: 0.5612
# Epoch 128/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5236 - mae: 0.5609 - val_loss: 0.5846 - val_mae: 0.6150
# Epoch 129/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4859 - mae: 0.5421 - val_loss: 0.5662 - val_mae: 0.6042
# Epoch 130/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5314 - mae: 0.5691 - val_loss: 0.4949 - val_mae: 0.5606
# Epoch 131/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5010 - mae: 0.5528 - val_loss: 0.5098 - val_mae: 0.5627
# Epoch 132/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5215 - mae: 0.5594 - val_loss: 0.5132 - val_mae: 0.5721
# Epoch 133/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5228 - mae: 0.5647 - val_loss: 0.4902 - val_mae: 0.5568
# Epoch 134/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5299 - mae: 0.5723 - val_loss: 0.5192 - val_mae: 0.5666
# Epoch 135/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5279 - mae: 0.5590 - val_loss: 0.4974 - val_mae: 0.5583
# Epoch 136/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4892 - mae: 0.5476 - val_loss: 0.5319 - val_mae: 0.5686
# Epoch 137/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5011 - mae: 0.5483 - val_loss: 0.5244 - val_mae: 0.5667
# Epoch 138/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5003 - mae: 0.5520 - val_loss: 0.5037 - val_mae: 0.5671
# Epoch 139/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5333 - mae: 0.5631 - val_loss: 0.5149 - val_mae: 0.5752
# Epoch 140/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4927 - mae: 0.5498 - val_loss: 0.5510 - val_mae: 0.5716
# Epoch 141/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5220 - mae: 0.5688 - val_loss: 0.5058 - val_mae: 0.5626
# Epoch 142/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4837 - mae: 0.5450 - val_loss: 0.6178 - val_mae: 0.6310
# Epoch 143/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5043 - mae: 0.5541 - val_loss: 0.5528 - val_mae: 0.5945
# Epoch 144/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4980 - mae: 0.5457 - val_loss: 0.4983 - val_mae: 0.5599
# Epoch 145/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4767 - mae: 0.5369 - val_loss: 0.5064 - val_mae: 0.5629
# Epoch 146/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5145 - mae: 0.5633 - val_loss: 0.5282 - val_mae: 0.5799
# Epoch 147/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5356 - mae: 0.5715 - val_loss: 0.5146 - val_mae: 0.5632
# Epoch 148/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5156 - mae: 0.5609 - val_loss: 0.4987 - val_mae: 0.5633
# Epoch 149/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4960 - mae: 0.5506 - val_loss: 0.4950 - val_mae: 0.5623
# Epoch 150/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5105 - mae: 0.5546 - val_loss: 0.4912 - val_mae: 0.5557
# Epoch 151/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5148 - mae: 0.5536 - val_loss: 0.4905 - val_mae: 0.5554
# Epoch 152/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4818 - mae: 0.5412 - val_loss: 0.4918 - val_mae: 0.5549
# Epoch 153/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4803 - mae: 0.5403 - val_loss: 0.5096 - val_mae: 0.5695
# Epoch 154/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4677 - mae: 0.5361 - val_loss: 0.4989 - val_mae: 0.5601
# Epoch 155/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5013 - mae: 0.5519 - val_loss: 0.5100 - val_mae: 0.5708
# Epoch 156/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5068 - mae: 0.5563 - val_loss: 0.5064 - val_mae: 0.5678
# Epoch 157/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4976 - mae: 0.5536 - val_loss: 0.4954 - val_mae: 0.5585
# Epoch 158/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4828 - mae: 0.5396 - val_loss: 0.5124 - val_mae: 0.5734
# Epoch 159/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5119 - mae: 0.5558 - val_loss: 0.5248 - val_mae: 0.5794
# Epoch 160/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5054 - mae: 0.5562 - val_loss: 0.5157 - val_mae: 0.5749
# Epoch 161/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4995 - mae: 0.5514 - val_loss: 0.5681 - val_mae: 0.5989
# Epoch 162/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5194 - mae: 0.5621 - val_loss: 0.5002 - val_mae: 0.5674
# Epoch 163/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5144 - mae: 0.5608 - val_loss: 0.5018 - val_mae: 0.5571
# Epoch 164/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4783 - mae: 0.5423 - val_loss: 0.5336 - val_mae: 0.5816
# Epoch 165/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4771 - mae: 0.5406 - val_loss: 0.4906 - val_mae: 0.5574
# Epoch 166/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4887 - mae: 0.5452 - val_loss: 0.5682 - val_mae: 0.5991
# Epoch 167/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5164 - mae: 0.5508 - val_loss: 0.5481 - val_mae: 0.5954
# Epoch 168/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5057 - mae: 0.5534 - val_loss: 0.5279 - val_mae: 0.5674
# Epoch 169/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4947 - mae: 0.5472 - val_loss: 0.5505 - val_mae: 0.5741
# Epoch 170/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5126 - mae: 0.5621 - val_loss: 0.5029 - val_mae: 0.5626
# Epoch 171/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4929 - mae: 0.5463 - val_loss: 0.6053 - val_mae: 0.6286
# Epoch 172/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5351 - mae: 0.5717 - val_loss: 0.5297 - val_mae: 0.5642
# Epoch 173/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4932 - mae: 0.5475 - val_loss: 0.4985 - val_mae: 0.5610
# Epoch 174/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4808 - mae: 0.5447 - val_loss: 0.5017 - val_mae: 0.5630
# Epoch 175/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5080 - mae: 0.5586 - val_loss: 0.5017 - val_mae: 0.5580
# Epoch 176/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5198 - mae: 0.5663 - val_loss: 0.5093 - val_mae: 0.5609
# Epoch 177/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5005 - mae: 0.5478 - val_loss: 0.5019 - val_mae: 0.5586
# Epoch 178/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5016 - mae: 0.5500 - val_loss: 0.5142 - val_mae: 0.5697
# Epoch 179/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5063 - mae: 0.5526 - val_loss: 0.5241 - val_mae: 0.5678
# Epoch 180/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4869 - mae: 0.5408 - val_loss: 0.5394 - val_mae: 0.5694
# Epoch 181/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5025 - mae: 0.5587 - val_loss: 0.5076 - val_mae: 0.5664
# Epoch 182/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4788 - mae: 0.5401 - val_loss: 0.5172 - val_mae: 0.5742
# Epoch 183/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4944 - mae: 0.5554 - val_loss: 0.5144 - val_mae: 0.5725
# Epoch 184/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4892 - mae: 0.5475 - val_loss: 0.5071 - val_mae: 0.5623
# Epoch 185/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4562 - mae: 0.5278 - val_loss: 0.5364 - val_mae: 0.5866
# Epoch 186/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4803 - mae: 0.5421 - val_loss: 0.5033 - val_mae: 0.5646
# Epoch 187/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5035 - mae: 0.5562 - val_loss: 0.5027 - val_mae: 0.5581
# Epoch 188/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4910 - mae: 0.5504 - val_loss: 0.5088 - val_mae: 0.5608
# Epoch 189/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4655 - mae: 0.5353 - val_loss: 0.5074 - val_mae: 0.5677
# Epoch 190/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4922 - mae: 0.5494 - val_loss: 0.4942 - val_mae: 0.5591
# Epoch 191/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4953 - mae: 0.5467 - val_loss: 0.5478 - val_mae: 0.5779
# Epoch 192/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4978 - mae: 0.5457 - val_loss: 0.5175 - val_mae: 0.5605
# Epoch 193/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4837 - mae: 0.5441 - val_loss: 0.5203 - val_mae: 0.5765
# Epoch 194/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4785 - mae: 0.5475 - val_loss: 0.5022 - val_mae: 0.5556
# Epoch 195/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4920 - mae: 0.5442 - val_loss: 0.5154 - val_mae: 0.5759
# Epoch 196/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5144 - mae: 0.5581 - val_loss: 0.5106 - val_mae: 0.5627
# Epoch 197/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4708 - mae: 0.5369 - val_loss: 0.5121 - val_mae: 0.5733
# Epoch 198/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4758 - mae: 0.5404 - val_loss: 0.5082 - val_mae: 0.5676
# Epoch 199/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4890 - mae: 0.5451 - val_loss: 0.5087 - val_mae: 0.5633
# Epoch 200/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4688 - mae: 0.5348 - val_loss: 0.5214 - val_mae: 0.5746

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5559 - mae: 0.5848
# Test Loss: [0.6145347952842712, 0.6010316014289856]

# %% [markdown]
# <a name='1.2'></a>
# ## Cuestión 2: Utilice el mismo modelo de la cuestión anterior pero añadiendo al menos dos técnicas distinas de regularización. No es necesario reducir el test loss.
#
# Ejemplos de regularización: [Prevent_Overfitting.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb)

# %%
model = tf.keras.models.Sequential()
# Código aquí
...

# %%
# Compilación del modelo
# Código aquí
model.compile(...)

# %%
batch_size=...

# %%
# No modifique el código
model.fit(x_train,
          y_train,
          epochs=200,
          batch_size=batch_size,
          validation_split=0.2,
          verbose=1)

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))

# %% [markdown]
# <a name='1.3'></a>
# ## Cuestión 3: Utilice el mismo modelo de la cuestión anterior pero añadiendo un callback de early stopping. No es necesario reducir el test loss.

# %%
model = tf.keras.models.Sequential()
# Código aquí
...

# %%
# Compilación del modelo
# Código aquí
model.compile(...)

# %%
## definir el early stopping callback
# Código aquí
...
model.fit(x_train,
          y_train,
          epochs=200,
          batch_size=32,
          validation_split=0.2,
          verbose=1,
          callbacks=[...]) # Código aquí

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))

# %% [markdown]
# <a name='1.4'></a>
# ## Cuestión 4: ¿Podría haberse usado otra función de activación de la neurona de salida? En caso afirmativo especifíquela.

# %% [markdown]
# <a name='1.5'></a>
# ## Cuestión 5:  ¿Qué es lo que una neurona calcula?
#
# **a)** Una función de activación seguida de una suma ponderada  de las entradas.
#
# **b)** Una suma ponderada  de las entradas seguida de una función de activación.
#
# **c)** Una función de pérdida, definida sobre el target.
#
# **d)** Ninguna  de las anteriores es correcta

# %% [markdown]
# <a name='1.6'></a>
# ## Cuestión 6:  ¿Cuál de estas funciones de activación no debería usarse en una capa oculta (hidden layer)?
#
# **a)** `sigmoid`
#
# **b)** `tanh`
#
# **c)** `relu`
#
# **d)** `linear`

# %% [markdown]
# <a name='1.7'></a>
# ## Cuestión 7:  ¿Cuál de estas técnicas es efectiva para combatir el overfitting en una red con varias capas ocultas? Ponga todas las que lo sean.
#
# **a)** Dropout
#
# **b)** Regularización L2.
#
# **c)** Aumentar el tamaño del test set.
#
# **d)** Aumentar el tamaño del validation set.
#
# **e)** Reducir el número de capas de la red.
#
# **f)** Data augmentation.

# %% [markdown]
# <a name='1.8'></a>
# ## Cuestión 8:  Supongamos que queremos entrenar una red para un problema de clasificación de imágenes con las siguientes clases: {'perro','gato','persona'}. ¿Cuántas neuronas y que función de activación debería tener la capa de salida? ¿Qué función de pérdida (loss function) debería usarse?
